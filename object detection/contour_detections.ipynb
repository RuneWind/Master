# %%
import pandas as pd
import os
import time
import cv2 as cv
import numpy as np
from shapely.geometry import Polygon
from shutil import copyfile
from IPython.display import clear_output

# %%
all_imgs = os.listdir("test_data_10000")
bb_df = pd.read_csv("../bounding_box_data.csv", sep=",")
bb_df.head(5)
# Out:
#             deviceID             timestamp    x    y  width  height
# 0  0a:92:5e:29:ec:a2  20191225T000100+0900  660  388    125     125
# 1  0a:92:5e:29:ec:a2  20191225T000606+0900  660  388    125     125
# 2  0a:92:5e:29:ec:a2  20191225T001111+0900  660  388    125     125
# 3  0a:92:5e:29:ec:a2  20191225T001617+0900  660  388    125     125
# 4  0a:92:5e:29:ec:a2  20191225T002120+0900  660  388    125     125

# %%
all_filtered_cons = []
for i in range(len(all_imgs)):
    if not all_imgs[i].endswith(".png"):
        continue
    img = cv.imread("test_data_10000/" + all_imgs[i], cv.COLOR_BGR2GRAY)

    thresh = cv.adaptiveThreshold(src=img, maxValue=255, adaptiveMethod=cv.ADAPTIVE_THRESH_GAUSSIAN_C, thresholdType=cv.THRESH_BINARY_INV, blockSize=1001, C=5)
    thresh = thresh.astype(np.uint8)

    # Find countours
    contours, hierarchy = cv.findContours(image=thresh, mode=cv.RETR_TREE, method=cv.CHAIN_APPROX_NONE)[-2:]

    # Filter contours by size
    filtered_contours = []
    for con in contours:
        hull = cv.convexHull(con)
        hull_area = cv.contourArea(hull)
        con_area = cv.contourArea(con)
        x, y, w, h = cv.boundingRect(con)

        # Continue if hull area is too small or too large
        if hull_area > 40000 or hull_area < 11000:
            continue
        # Continue if hull is too close to image borders
        if (x == 0 or x > 960) or (y == 0 or y > 500):
            continue
        
        solidity = con_area / hull_area
        aspect_ratio = w / h
        if aspect_ratio > 0.8 and aspect_ratio < 1.25 and solidity > 0.5:
            filtered_contours.append(con)
    
    print("{i}\t: {filt_cons} out of {all_cons} contours passed filtering".format(i=i, filt_cons=len(filtered_contours), all_cons=len(contours)))
    all_filtered_cons.append([filtered_contours, all_imgs[i]])
    # for con in filtered_contours:
    #     x, y, w, h = cv.boundingRect(con)
    #     cv.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
    #     cv.putText(img, "WEIGHER?", (x, y-8), cv.FONT_HERSHEY_SIMPLEX, 0.8, (255, 0, 0), 2, cv.LINE_AA)

    # cv.imshow("Bounding Boxes", img)
    # k = cv.waitKey(0)
    # cv.destroyWindow("Bounding Boxes")
    # cv.waitKey(1)
    # if k == ord("q"):
    #     break
# Out:
# 0	: 0 out of 4050 contours passed filtering
# 1	: 0 out of 3227 contours passed filtering
# 2	: 0 out of 2301 contours passed filtering
# 3	: 0 out of 1687 contours passed filtering
# 4	: 0 out of 3053 contours passed filtering
# 5	: 0 out of 2887 contours passed filtering
# 6	: 1 out of 3788 contours passed filtering
# 7	: 0 out of 2073 contours passed filtering
# 8	: 0 out of 2835 contours passed filtering
# 9	: 0 out of 2419 contours passed filtering
# 10	: 0 out of 2866 contours passed filtering
# 11	: 0 out of 2458 contours passed filtering
# 12	: 0 out of 2134 contours passed filtering
# 13	: 0 out of 2901 contours passed filtering
# 14	: 0 out of 2365 contours passed filtering
# 15	: 1 out of 2262 contours passed filtering
# 16	: 0 out of 2902 contours passed filtering
# 17	: 0 out of 2842 contours passed filtering
# 18	: 1 out of 4067 contours passed filtering
# 19	: 1 out of 3227 contours passed filtering
# 20	: 0 out of 2768 contours passed filtering
# 21	: 0 out of 3972 contours passed filtering
# 22	: 0 out of 2813 contours passed filtering
# 23	: 0 out of 1871 contours passed filtering
# 24	: 0 out of 2681 contours passed filtering
# 25	: 0 out of 3019 contours passed filtering
# 26	: 0 out of 2866 contours passed filtering
# 27	: 0 out of 2531 contours passed filtering
# 28	: 0 out of 2095 contours passed filtering
# 29	: 0 out of 2584 contours passed filtering
# 30	: 0 out of 2542 contours passed filtering
# 31	: 0 out of 3096 contours passed filtering
# 32	: 0 out of 2053 contours passed filtering
# 33	: 0 out of 2572 contours passed filtering
# 34	: 0 out of 2505 contours passed filtering
# 35	: 0 out of 2903 contours passed filtering
# 36	: 1 out of 2032 contours passed filtering
# 37	: 2 out of 3020 contours passed filtering
# 38	: 0 out of 2347 contours passed filtering
# 39	: 0 out of 2597 contours passed filtering
# 40	: 0 out of 1958 contours passed filtering
# 41	: 0 out of 1903 contours passed filtering
# 42	: 0 out of 3756 contours passed filtering
# 43	: 0 out of 2341 contours passed filtering
# 44	: 0 out of 2685 contours passed filtering
# 45	: 0 out of 3131 contours passed filtering
# 46	: 0 out of 2805 contours passed filtering
# 47	: 0 out of 2961 contours passed filtering
# 48	: 0 out of 3648 contours passed filtering
# 49	: 0 out of 3764 contours passed filtering
# 50	: 0 out of 3576 contours passed filtering
# 51	: 0 out of 1546 contours passed filtering
# 52	: 0 out of 2529 contours passed filtering
# 53	: 0 out of 2147 contours passed filtering
# 54	: 0 out of 2746 contours passed filtering
# 55	: 0 out of 3083 contours passed filtering
# 56	: 1 out of 2912 contours passed filtering
# 57	: 0 out of 3305 contours passed filtering
# 58	: 0 out of 1702 contours passed filtering
# 59	: 0 out of 2780 contours passed filtering
# 60	: 0 out of 2637 contours passed filtering
# 61	: 1 out of 2483 contours passed filtering
# 62	: 0 out of 2858 contours passed filtering
# 63	: 1 out of 3255 contours passed filtering
# 64	: 0 out of 2604 contours passed filtering
# 65	: 0 out of 2934 contours passed filtering
# 66	: 0 out of 2858 contours passed filtering
# 67	: 0 out of 3083 contours passed filtering
# 68	: 1 out of 3032 contours passed filtering
# 69	: 0 out of 2230 contours passed filtering
# 70	: 0 out of 2484 contours passed filtering
# 71	: 0 out of 2672 contours passed filtering
# 72	: 0 out of 2999 contours passed filtering
# 73	: 0 out of 3137 contours passed filtering
# 74	: 0 out of 1524 contours passed filtering
# 75	: 0 out of 3404 contours passed filtering
# 76	: 0 out of 1897 contours passed filtering
# 77	: 0 out of 2133 contours passed filtering
# 78	: 0 out of 3244 contours passed filtering
# 79	: 0 out of 3181 contours passed filtering
# 80	: 1 out of 2951 contours passed filtering
# 81	: 0 out of 3057 contours passed filtering
# 82	: 1 out of 2143 contours passed filtering
# 83	: 0 out of 2991 contours passed filtering
# 84	: 0 out of 3517 contours passed filtering
# 85	: 0 out of 2807 contours passed filtering
# 86	: 0 out of 2861 contours passed filtering
# 87	: 0 out of 3232 contours passed filtering
# 88	: 0 out of 3182 contours passed filtering
# 89	: 0 out of 2360 contours passed filtering
# 90	: 0 out of 3302 contours passed filtering
# 91	: 0 out of 2659 contours passed filtering
# 92	: 0 out of 3522 contours passed filtering
# 93	: 0 out of 2082 contours passed filtering
# 94	: 0 out of 2767 contours passed filtering
# 95	: 0 out of 3106 contours passed filtering
# 96	: 0 out of 3031 contours passed filtering
# 97	: 0 out of 2868 contours passed filtering
# 98	: 0 out of 2187 contours passed filtering
# 99	: 0 out of 3769 contours passed filtering
# 100	: 1 out of 2990 contours passed filtering
# 101	: 0 out of 6704 contours passed filtering
# 102	: 1 out of 2457 contours passed filtering
# 103	: 0 out of 2481 contours passed filtering
# 104	: 0 out of 3235 contours passed filtering
# 105	: 0 out of 2813 contours passed filtering
# 106	: 0 out of 2718 contours passed filtering
# 107	: 0 out of 2574 contours passed filtering
# 108	: 0 out of 3081 contours passed filtering
# 109	: 0 out of 3060 contours passed filtering
# 110	: 1 out of 1952 contours passed filtering
# 111	: 0 out of 3518 contours passed filtering
# 112	: 0 out of 2834 contours passed filtering
# 113	: 0 out of 3080 contours passed filtering
# 114	: 0 out of 3365 contours passed filtering
# 115	: 0 out of 3163 contours passed filtering
# 116	: 1 out of 2137 contours passed filtering
# 117	: 0 out of 2346 contours passed filtering
# 118	: 0 out of 2998 contours passed filtering
# 119	: 0 out of 2258 contours passed filtering
# 120	: 0 out of 2811 contours passed filtering
# 121	: 0 out of 2645 contours passed filtering
# 122	: 1 out of 2951 contours passed filtering
# 123	: 0 out of 3888 contours passed filtering
# 124	: 1 out of 2786 contours passed filtering
# 125	: 0 out of 2230 contours passed filtering
# 126	: 1 out of 3986 contours passed filtering
# 127	: 0 out of 5155 contours passed filtering
# 128	: 0 out of 2344 contours passed filtering
# 129	: 1 out of 3379 contours passed filtering
# 130	: 0 out of 3558 contours passed filtering
# 131	: 0 out of 3186 contours passed filtering
# 132	: 0 out of 2603 contours passed filtering
# 133	: 0 out of 2398 contours passed filtering
# 134	: 0 out of 3112 contours passed filtering
# 135	: 1 out of 2446 contours passed filtering
# 136	: 0 out of 2061 contours passed filtering
# 137	: 0 out of 2468 contours passed filtering
# 138	: 0 out of 2164 contours passed filtering
# 139	: 0 out of 2102 contours passed filtering
# 140	: 0 out of 2796 contours passed filtering
# 141	: 0 out of 2573 contours passed filtering
# 142	: 0 out of 3978 contours passed filtering
# 143	: 0 out of 2313 contours passed filtering
# 144	: 0 out of 2774 contours passed filtering
# 145	: 0 out of 2000 contours passed filtering
# 146	: 0 out of 2973 contours passed filtering
# 147	: 0 out of 4254 contours passed filtering
# 148	: 0 out of 3009 contours passed filtering
# 149	: 0 out of 2356 contours passed filtering
# 150	: 1 out of 2138 contours passed filtering
# 151	: 0 out of 3884 contours passed filtering
# 152	: 0 out of 2241 contours passed filtering
# 153	: 0 out of 3535 contours passed filtering
# 154	: 0 out of 3796 contours passed filtering
# 155	: 0 out of 3095 contours passed filtering
# 156	: 0 out of 2916 contours passed filtering
# 157	: 0 out of 2532 contours passed filtering
# 158	: 0 out of 3045 contours passed filtering
# 159	: 0 out of 3816 contours passed filtering
# 160	: 0 out of 3790 contours passed filtering
# 161	: 0 out of 3463 contours passed filtering
# 162	: 1 out of 3049 contours passed filtering
# 163	: 0 out of 2012 contours passed filtering
# 164	: 0 out of 3226 contours passed filtering
# 165	: 0 out of 2543 contours passed filtering
# 166	: 0 out of 2816 contours passed filtering
# 167	: 1 out of 2920 contours passed filtering
# 168	: 0 out of 2617 contours passed filtering
# 169	: 0 out of 2220 contours passed filtering
# 170	: 1 out of 3622 contours passed filtering
# 171	: 0 out of 2748 contours passed filtering
# 172	: 0 out of 1782 contours passed filtering
# 173	: 0 out of 2760 contours passed filtering
# 174	: 0 out of 4049 contours passed filtering
# 175	: 0 out of 2719 contours passed filtering
# 176	: 0 out of 2345 contours passed filtering
# 177	: 1 out of 2603 contours passed filtering
# 178	: 0 out of 3388 contours passed filtering
# 179	: 0 out of 2359 contours passed filtering
# 180	: 0 out of 2747 contours passed filtering
# 181	: 0 out of 2132 contours passed filtering
# 182	: 1 out of 3057 contours passed filtering
# 183	: 0 out of 2567 contours passed filtering
# 184	: 0 out of 2926 contours passed filtering
# 185	: 0 out of 2690 contours passed filtering
# 186	: 0 out of 2342 contours passed filtering
# 187	: 0 out of 2112 contours passed filtering
# 188	: 0 out of 2865 contours passed filtering
# 189	: 1 out of 2165 contours passed filtering
# 190	: 0 out of 1907 contours passed filtering
# 191	: 0 out of 2142 contours passed filtering
# 192	: 1 out of 1849 contours passed filtering
# 193	: 0 out of 2433 contours passed filtering
# 194	: 1 out of 2110 contours passed filtering
# 195	: 0 out of 3155 contours passed filtering
# 196	: 0 out of 2903 contours passed filtering
# 197	: 0 out of 2663 contours passed filtering
# 198	: 0 out of 3455 contours passed filtering
# 199	: 0 out of 3248 contours passed filtering
# 200	: 1 out of 2168 contours passed filtering
# 201	: 0 out of 2830 contours passed filtering
# 202	: 0 out of 3558 contours passed filtering
# 203	: 1 out of 3113 contours passed filtering
# 204	: 0 out of 2903 contours passed filtering
# 205	: 0 out of 3050 contours passed filtering
# 206	: 0 out of 3085 contours passed filtering
# 207	: 0 out of 2753 contours passed filtering
# 208	: 0 out of 2257 contours passed filtering
# 209	: 1 out of 2879 contours passed filtering
# 210	: 0 out of 3408 contours passed filtering
# 211	: 0 out of 2543 contours passed filtering
# 212	: 1 out of 2455 contours passed filtering
# 213	: 0 out of 3003 contours passed filtering
# 214	: 0 out of 2536 contours passed filtering
# 215	: 0 out of 2412 contours passed filtering
# 216	: 0 out of 2651 contours passed filtering
# 217	: 0 out of 2585 contours passed filtering
# 218	: 0 out of 3542 contours passed filtering
# 219	: 0 out of 2707 contours passed filtering
# 220	: 0 out of 1898 contours passed filtering
# 221	: 0 out of 3183 contours passed filtering
# 222	: 0 out of 3211 contours passed filtering
# 223	: 0 out of 3110 contours passed filtering
# 224	: 0 out of 2019 contours passed filtering
# 225	: 0 out of 2056 contours passed filtering
# 226	: 0 out of 2104 contours passed filtering
# 227	: 0 out of 2224 contours passed filtering
# 228	: 0 out of 1775 contours passed filtering
# 229	: 0 out of 2725 contours passed filtering
# 230	: 0 out of 2073 contours passed filtering
# 231	: 0 out of 2276 contours passed filtering
# 232	: 0 out of 2988 contours passed filtering
# 233	: 1 out of 2933 contours passed filtering
# 234	: 0 out of 1896 contours passed filtering
# 235	: 0 out of 2293 contours passed filtering
# 236	: 0 out of 2462 contours passed filtering
# 237	: 1 out of 2878 contours passed filtering
# 238	: 0 out of 2298 contours passed filtering
# 239	: 1 out of 3093 contours passed filtering
# 240	: 0 out of 2229 contours passed filtering
# 241	: 0 out of 2263 contours passed filtering
# 242	: 0 out of 3788 contours passed filtering
# 243	: 0 out of 2904 contours passed filtering
# 244	: 1 out of 2787 contours passed filtering
# 245	: 0 out of 2891 contours passed filtering
# 246	: 0 out of 3136 contours passed filtering
# 247	: 0 out of 1893 contours passed filtering
# 248	: 0 out of 2690 contours passed filtering
# 249	: 1 out of 2341 contours passed filtering
# 250	: 0 out of 3581 contours passed filtering
# 251	: 0 out of 3032 contours passed filtering
# 252	: 0 out of 2737 contours passed filtering
# 253	: 0 out of 1929 contours passed filtering
# 254	: 0 out of 2059 contours passed filtering
# 255	: 0 out of 2960 contours passed filtering
# 256	: 0 out of 2925 contours passed filtering
# 257	: 0 out of 3495 contours passed filtering
# 258	: 0 out of 2098 contours passed filtering
# 259	: 0 out of 2123 contours passed filtering
# 260	: 0 out of 2717 contours passed filtering
# 261	: 0 out of 2358 contours passed filtering
# 262	: 0 out of 2662 contours passed filtering
# 263	: 0 out of 2917 contours passed filtering
# 264	: 0 out of 2130 contours passed filtering
# 265	: 0 out of 3253 contours passed filtering
# 266	: 1 out of 1695 contours passed filtering
# 267	: 0 out of 2030 contours passed filtering
# 268	: 0 out of 3525 contours passed filtering
# 269	: 0 out of 3418 contours passed filtering
# 270	: 0 out of 2709 contours passed filtering
# 271	: 0 out of 2115 contours passed filtering
# 272	: 0 out of 2094 contours passed filtering
# 273	: 0 out of 2862 contours passed filtering
# 274	: 0 out of 2267 contours passed filtering
# 275	: 0 out of 2896 contours passed filtering
# 276	: 0 out of 1904 contours passed filtering
# 277	: 0 out of 2849 contours passed filtering
# 278	: 0 out of 3114 contours passed filtering
# 279	: 0 out of 2867 contours passed filtering
# 280	: 1 out of 3201 contours passed filtering
# 281	: 0 out of 3412 contours passed filtering
# 282	: 0 out of 3259 contours passed filtering
# 283	: 0 out of 2184 contours passed filtering
# 284	: 0 out of 2185 contours passed filtering
# 285	: 0 out of 2262 contours passed filtering
# 286	: 0 out of 2790 contours passed filtering
# 287	: 0 out of 2670 contours passed filtering
# 288	: 0 out of 2488 contours passed filtering
# 289	: 0 out of 1641 contours passed filtering
# 290	: 0 out of 2067 contours passed filtering
# 291	: 0 out of 3044 contours passed filtering
# 292	: 0 out of 2534 contours passed filtering
# 293	: 1 out of 2983 contours passed filtering
# 294	: 1 out of 2332 contours passed filtering
# 295	: 0 out of 2601 contours passed filtering
# 296	: 1 out of 2137 contours passed filtering
# 297	: 0 out of 3187 contours passed filtering
# 298	: 0 out of 2863 contours passed filtering
# 299	: 0 out of 2163 contours passed filtering
# 300	: 0 out of 3231 contours passed filtering
# 301	: 1 out of 2809 contours passed filtering
# 302	: 0 out of 2331 contours passed filtering
# 303	: 1 out of 2272 contours passed filtering
# 304	: 1 out of 2586 contours passed filtering
# 305	: 1 out of 2289 contours passed filtering
# 306	: 0 out of 2423 contours passed filtering
# 307	: 1 out of 2507 contours passed filtering
# 308	: 1 out of 2011 contours passed filtering
# 309	: 0 out of 1916 contours passed filtering
# 310	: 0 out of 3228 contours passed filtering
# 311	: 0 out of 1925 contours passed filtering
# 312	: 0 out of 2244 contours passed filtering
# 313	: 1 out of 2742 contours passed filtering
# 314	: 1 out of 3099 contours passed filtering
# 315	: 0 out of 2852 contours passed filtering
# 316	: 0 out of 2726 contours passed filtering
# 317	: 0 out of 2615 contours passed filtering
# 318	: 0 out of 2455 contours passed filtering
# 319	: 0 out of 2932 contours passed filtering
# 320	: 0 out of 2433 contours passed filtering
# 321	: 0 out of 2086 contours passed filtering
# 322	: 0 out of 3685 contours passed filtering
# 323	: 0 out of 2301 contours passed filtering
# 324	: 0 out of 3145 contours passed filtering
# 325	: 0 out of 2334 contours passed filtering
# 326	: 0 out of 1979 contours passed filtering
# 327	: 0 out of 3000 contours passed filtering
# 328	: 0 out of 2389 contours passed filtering
# 329	: 0 out of 2035 contours passed filtering
# 330	: 0 out of 3122 contours passed filtering
# 331	: 0 out of 2856 contours passed filtering
# 332	: 0 out of 2794 contours passed filtering
# 333	: 0 out of 3092 contours passed filtering
# 334	: 0 out of 6685 contours passed filtering
# 335	: 0 out of 2137 contours passed filtering
# 336	: 0 out of 2776 contours passed filtering
# 337	: 0 out of 2199 contours passed filtering
# 338	: 0 out of 2163 contours passed filtering
# 339	: 1 out of 2958 contours passed filtering
# 340	: 2 out of 2819 contours passed filtering
# 341	: 0 out of 2193 contours passed filtering
# 342	: 1 out of 2884 contours passed filtering
# 343	: 0 out of 3017 contours passed filtering
# 344	: 0 out of 2846 contours passed filtering
# 345	: 0 out of 3148 contours passed filtering
# 346	: 0 out of 1805 contours passed filtering
# 347	: 0 out of 3570 contours passed filtering
# 348	: 0 out of 2564 contours passed filtering
# 349	: 0 out of 3014 contours passed filtering
# 350	: 1 out of 3835 contours passed filtering
# 351	: 1 out of 2191 contours passed filtering
# 352	: 0 out of 3159 contours passed filtering
# 353	: 0 out of 2862 contours passed filtering
# 354	: 0 out of 2807 contours passed filtering
# 355	: 0 out of 3127 contours passed filtering
# 356	: 1 out of 2508 contours passed filtering
# 357	: 0 out of 2149 contours passed filtering
# 358	: 0 out of 2962 contours passed filtering
# 359	: 0 out of 2941 contours passed filtering
# 360	: 0 out of 3122 contours passed filtering
# 361	: 0 out of 2899 contours passed filtering
# 362	: 0 out of 2792 contours passed filtering
# 363	: 0 out of 2140 contours passed filtering
# 364	: 0 out of 2846 contours passed filtering
# 365	: 1 out of 2211 contours passed filtering
# 366	: 0 out of 3176 contours passed filtering
# 367	: 0 out of 2655 contours passed filtering
# 368	: 1 out of 2208 contours passed filtering
# 369	: 1 out of 2184 contours passed filtering
# 370	: 0 out of 2391 contours passed filtering
# 371	: 0 out of 2788 contours passed filtering
# 372	: 0 out of 2923 contours passed filtering
# 373	: 0 out of 2763 contours passed filtering
# 374	: 0 out of 2952 contours passed filtering
# 375	: 0 out of 2919 contours passed filtering
# 376	: 0 out of 3941 contours passed filtering
# 377	: 0 out of 2792 contours passed filtering
# 378	: 0 out of 2250 contours passed filtering
# 379	: 0 out of 3082 contours passed filtering
# 380	: 0 out of 2375 contours passed filtering
# 381	: 0 out of 2114 contours passed filtering
# 382	: 0 out of 1822 contours passed filtering
# 383	: 0 out of 2416 contours passed filtering
# 384	: 0 out of 3874 contours passed filtering
# 385	: 0 out of 3196 contours passed filtering
# 386	: 0 out of 2602 contours passed filtering
# 387	: 0 out of 2437 contours passed filtering
# 388	: 0 out of 2333 contours passed filtering
# 389	: 0 out of 2616 contours passed filtering
# 390	: 0 out of 2831 contours passed filtering
# 391	: 0 out of 3867 contours passed filtering
# 392	: 1 out of 2955 contours passed filtering
# 393	: 0 out of 3225 contours passed filtering
# 394	: 0 out of 3699 contours passed filtering
# 395	: 0 out of 2089 contours passed filtering
# 396	: 0 out of 3079 contours passed filtering
# 397	: 0 out of 3820 contours passed filtering
# 398	: 0 out of 3468 contours passed filtering
# 399	: 0 out of 2524 contours passed filtering
# 400	: 0 out of 2824 contours passed filtering
# 401	: 0 out of 2923 contours passed filtering
# 402	: 0 out of 3094 contours passed filtering
# 403	: 0 out of 2037 contours passed filtering
# 404	: 0 out of 2046 contours passed filtering
# 405	: 0 out of 2148 contours passed filtering
# 406	: 0 out of 2874 contours passed filtering
# 407	: 0 out of 1989 contours passed filtering
# 408	: 1 out of 3038 contours passed filtering
# 409	: 0 out of 1954 contours passed filtering
# 410	: 0 out of 2292 contours passed filtering
# 411	: 0 out of 2439 contours passed filtering
# 412	: 0 out of 2777 contours passed filtering
# 413	: 1 out of 2191 contours passed filtering
# 414	: 0 out of 3523 contours passed filtering
# 415	: 0 out of 2759 contours passed filtering
# 416	: 0 out of 2263 contours passed filtering
# 417	: 0 out of 3115 contours passed filtering
# 418	: 1 out of 2761 contours passed filtering
# 419	: 0 out of 1937 contours passed filtering
# 420	: 1 out of 2162 contours passed filtering
# 421	: 0 out of 1939 contours passed filtering
# 422	: 0 out of 2140 contours passed filtering
# 423	: 0 out of 3141 contours passed filtering
# 424	: 0 out of 3221 contours passed filtering
# 425	: 0 out of 2881 contours passed filtering
# 426	: 0 out of 2049 contours passed filtering
# 427	: 0 out of 3124 contours passed filtering
# 428	: 0 out of 2699 contours passed filtering
# 429	: 0 out of 3078 contours passed filtering
# 430	: 1 out of 2942 contours passed filtering
# 431	: 1 out of 3487 contours passed filtering
# 432	: 0 out of 2839 contours passed filtering
# 433	: 0 out of 3627 contours passed filtering
# 434	: 0 out of 3074 contours passed filtering
# 435	: 0 out of 2273 contours passed filtering
# 436	: 0 out of 1981 contours passed filtering
# 437	: 1 out of 3112 contours passed filtering
# 438	: 0 out of 2742 contours passed filtering
# 439	: 0 out of 2014 contours passed filtering
# 440	: 0 out of 2958 contours passed filtering
# 441	: 0 out of 2641 contours passed filtering
# 442	: 0 out of 3652 contours passed filtering
# 443	: 0 out of 3070 contours passed filtering
# 444	: 0 out of 2347 contours passed filtering
# 445	: 0 out of 2047 contours passed filtering
# 446	: 1 out of 2625 contours passed filtering
# 447	: 0 out of 2874 contours passed filtering
# 448	: 0 out of 2275 contours passed filtering
# 449	: 0 out of 2255 contours passed filtering
# 450	: 0 out of 2851 contours passed filtering
# 451	: 0 out of 3081 contours passed filtering
# 452	: 1 out of 2226 contours passed filtering
# 453	: 0 out of 3745 contours passed filtering
# 454	: 1 out of 3134 contours passed filtering
# 455	: 0 out of 2646 contours passed filtering
# 456	: 0 out of 3068 contours passed filtering
# 457	: 0 out of 3124 contours passed filtering
# 458	: 0 out of 3116 contours passed filtering
# 459	: 0 out of 2876 contours passed filtering
# 460	: 2 out of 2687 contours passed filtering
# 461	: 0 out of 3125 contours passed filtering
# 462	: 0 out of 2495 contours passed filtering
# 463	: 0 out of 3133 contours passed filtering
# 464	: 0 out of 2841 contours passed filtering
# 465	: 0 out of 2378 contours passed filtering
# 466	: 0 out of 3167 contours passed filtering
# 467	: 0 out of 3106 contours passed filtering
# 468	: 0 out of 3144 contours passed filtering
# 469	: 0 out of 2636 contours passed filtering
# 470	: 0 out of 3016 contours passed filtering
# 471	: 0 out of 2665 contours passed filtering
# 472	: 0 out of 2906 contours passed filtering
# 473	: 0 out of 2635 contours passed filtering
# 474	: 0 out of 1992 contours passed filtering
# 475	: 0 out of 1743 contours passed filtering
# 476	: 0 out of 3860 contours passed filtering
# 477	: 0 out of 2142 contours passed filtering
# 478	: 0 out of 2911 contours passed filtering
# 479	: 0 out of 2611 contours passed filtering
# 480	: 0 out of 1998 contours passed filtering
# 481	: 0 out of 2599 contours passed filtering
# 482	: 0 out of 2457 contours passed filtering
# 483	: 0 out of 2170 contours passed filtering
# 484	: 0 out of 3221 contours passed filtering
# 485	: 0 out of 2101 contours passed filtering
# 486	: 0 out of 2911 contours passed filtering
# 487	: 0 out of 2818 contours passed filtering
# 488	: 0 out of 2869 contours passed filtering
# 489	: 0 out of 3370 contours passed filtering
# 490	: 0 out of 2310 contours passed filtering
# 491	: 0 out of 2809 contours passed filtering
# 492	: 0 out of 3225 contours passed filtering
# 493	: 1 out of 4173 contours passed filtering
# 494	: 0 out of 2220 contours passed filtering
# 495	: 0 out of 3138 contours passed filtering
# 496	: 0 out of 3123 contours passed filtering
# 497	: 1 out of 3902 contours passed filtering
# 498	: 0 out of 2211 contours passed filtering
# 499	: 0 out of 2705 contours passed filtering
# 500	: 0 out of 2955 contours passed filtering
# 501	: 0 out of 2214 contours passed filtering
# 502	: 0 out of 2231 contours passed filtering
# 503	: 0 out of 2372 contours passed filtering
# 504	: 0 out of 2290 contours passed filtering
# 505	: 0 out of 2227 contours passed filtering
# 506	: 0 out of 2873 contours passed filtering
# 507	: 0 out of 2084 contours passed filtering
# 508	: 0 out of 2211 contours passed filtering
# 509	: 0 out of 4029 contours passed filtering
# 510	: 1 out of 2249 contours passed filtering
# 511	: 0 out of 2303 contours passed filtering
# 512	: 0 out of 2941 contours passed filtering
# 513	: 0 out of 2658 contours passed filtering
# 514	: 0 out of 2640 contours passed filtering
# 515	: 0 out of 3109 contours passed filtering
# 516	: 0 out of 2349 contours passed filtering
# 517	: 0 out of 1608 contours passed filtering
# 518	: 0 out of 2798 contours passed filtering
# 519	: 0 out of 2845 contours passed filtering
# 520	: 0 out of 3041 contours passed filtering
# 521	: 0 out of 2270 contours passed filtering
# 522	: 0 out of 2723 contours passed filtering
# 523	: 0 out of 2255 contours passed filtering
# 524	: 0 out of 2534 contours passed filtering
# 525	: 0 out of 2832 contours passed filtering
# 526	: 0 out of 3098 contours passed filtering
# 527	: 1 out of 2842 contours passed filtering
# 528	: 0 out of 2657 contours passed filtering
# 529	: 0 out of 3173 contours passed filtering
# 530	: 0 out of 1937 contours passed filtering
# 531	: 1 out of 3070 contours passed filtering
# 532	: 1 out of 3016 contours passed filtering
# 533	: 0 out of 2870 contours passed filtering
# 534	: 0 out of 2484 contours passed filtering
# 535	: 1 out of 3093 contours passed filtering
# 536	: 0 out of 3058 contours passed filtering
# 537	: 0 out of 2701 contours passed filtering
# 538	: 0 out of 2271 contours passed filtering
# 539	: 1 out of 2773 contours passed filtering
# 540	: 0 out of 2381 contours passed filtering
# 541	: 0 out of 2039 contours passed filtering
# 542	: 1 out of 2979 contours passed filtering
# 543	: 0 out of 2896 contours passed filtering
# 544	: 0 out of 2027 contours passed filtering
# 545	: 0 out of 2174 contours passed filtering
# 546	: 0 out of 2547 contours passed filtering
# 547	: 0 out of 2405 contours passed filtering
# 548	: 0 out of 2156 contours passed filtering
# 549	: 0 out of 2966 contours passed filtering
# 550	: 0 out of 2933 contours passed filtering
# 551	: 0 out of 2271 contours passed filtering
# 552	: 0 out of 2393 contours passed filtering
# 553	: 0 out of 2180 contours passed filtering
# 554	: 0 out of 3382 contours passed filtering
# 555	: 0 out of 2694 contours passed filtering
# 556	: 0 out of 2822 contours passed filtering
# 557	: 0 out of 3100 contours passed filtering
# 558	: 0 out of 3153 contours passed filtering
# 559	: 0 out of 1990 contours passed filtering
# 560	: 0 out of 2677 contours passed filtering
# 561	: 0 out of 2913 contours passed filtering
# 562	: 0 out of 2159 contours passed filtering
# 563	: 0 out of 2615 contours passed filtering
# 564	: 0 out of 2769 contours passed filtering
# 565	: 0 out of 2704 contours passed filtering
# 566	: 0 out of 3133 contours passed filtering
# 567	: 0 out of 2555 contours passed filtering
# 568	: 1 out of 1935 contours passed filtering
# 569	: 0 out of 3239 contours passed filtering
# 570	: 0 out of 2714 contours passed filtering
# 571	: 0 out of 2045 contours passed filtering
# 572	: 0 out of 2881 contours passed filtering
# 573	: 1 out of 2191 contours passed filtering
# 574	: 0 out of 3698 contours passed filtering
# 575	: 0 out of 2398 contours passed filtering
# 576	: 0 out of 3628 contours passed filtering
# 577	: 1 out of 2972 contours passed filtering
# 578	: 1 out of 3591 contours passed filtering
# 579	: 0 out of 2845 contours passed filtering
# 580	: 0 out of 3073 contours passed filtering
# 581	: 0 out of 2311 contours passed filtering
# 582	: 1 out of 2394 contours passed filtering
# 583	: 0 out of 3189 contours passed filtering
# 584	: 0 out of 2625 contours passed filtering
# 585	: 0 out of 3666 contours passed filtering
# 586	: 0 out of 3347 contours passed filtering
# 587	: 0 out of 2784 contours passed filtering
# 588	: 0 out of 2873 contours passed filtering
# 589	: 0 out of 1468 contours passed filtering
# 590	: 0 out of 2565 contours passed filtering
# 591	: 0 out of 3016 contours passed filtering
# 592	: 0 out of 2670 contours passed filtering
# 593	: 0 out of 2372 contours passed filtering
# 594	: 0 out of 1880 contours passed filtering
# 595	: 1 out of 2603 contours passed filtering
# 596	: 0 out of 1684 contours passed filtering
# 597	: 0 out of 2957 contours passed filtering
# 598	: 1 out of 2654 contours passed filtering
# 599	: 0 out of 2402 contours passed filtering
# 600	: 0 out of 2088 contours passed filtering
# 601	: 0 out of 2742 contours passed filtering
# 602	: 0 out of 2344 contours passed filtering
# 603	: 0 out of 2264 contours passed filtering
# 604	: 0 out of 3018 contours passed filtering
# 605	: 0 out of 2691 contours passed filtering
# 606	: 0 out of 2963 contours passed filtering
# 607	: 0 out of 3650 contours passed filtering
# 608	: 0 out of 3139 contours passed filtering
# 609	: 0 out of 3710 contours passed filtering
# 610	: 1 out of 2528 contours passed filtering
# 611	: 0 out of 2855 contours passed filtering
# 612	: 1 out of 1708 contours passed filtering
# 613	: 0 out of 2676 contours passed filtering
# 614	: 0 out of 2536 contours passed filtering
# 615	: 0 out of 2217 contours passed filtering
# 616	: 1 out of 3338 contours passed filtering
# 617	: 0 out of 2762 contours passed filtering
# 618	: 0 out of 2391 contours passed filtering
# 619	: 1 out of 2152 contours passed filtering
# 620	: 1 out of 3037 contours passed filtering
# 621	: 0 out of 2721 contours passed filtering
# 622	: 0 out of 2680 contours passed filtering
# 623	: 0 out of 3089 contours passed filtering
# 624	: 0 out of 2796 contours passed filtering
# 625	: 0 out of 2802 contours passed filtering
# 626	: 0 out of 2068 contours passed filtering
# 627	: 1 out of 3034 contours passed filtering
# 628	: 0 out of 2224 contours passed filtering
# 629	: 0 out of 2205 contours passed filtering
# 630	: 0 out of 2498 contours passed filtering
# 631	: 0 out of 2884 contours passed filtering
# 632	: 0 out of 1665 contours passed filtering
# 633	: 0 out of 2256 contours passed filtering
# 634	: 1 out of 2625 contours passed filtering
# 635	: 0 out of 3302 contours passed filtering
# 636	: 1 out of 3424 contours passed filtering
# 637	: 0 out of 2917 contours passed filtering
# 638	: 0 out of 2523 contours passed filtering
# 639	: 0 out of 3260 contours passed filtering
# 640	: 0 out of 1938 contours passed filtering
# 641	: 0 out of 3007 contours passed filtering
# 642	: 0 out of 2885 contours passed filtering
# 643	: 0 out of 3395 contours passed filtering
# 644	: 0 out of 3236 contours passed filtering
# 645	: 0 out of 2112 contours passed filtering
# 646	: 0 out of 3818 contours passed filtering
# 647	: 0 out of 2687 contours passed filtering
# 648	: 0 out of 1881 contours passed filtering
# 649	: 0 out of 1931 contours passed filtering
# 650	: 0 out of 2510 contours passed filtering
# 651	: 0 out of 3069 contours passed filtering
# 652	: 1 out of 2595 contours passed filtering
# 653	: 0 out of 2294 contours passed filtering
# 654	: 1 out of 2494 contours passed filtering
# 655	: 0 out of 2569 contours passed filtering
# 656	: 1 out of 2169 contours passed filtering
# 657	: 0 out of 2256 contours passed filtering
# 658	: 1 out of 2743 contours passed filtering
# 659	: 0 out of 3043 contours passed filtering
# 660	: 0 out of 2532 contours passed filtering
# 661	: 0 out of 2997 contours passed filtering
# 662	: 0 out of 2579 contours passed filtering
# 663	: 0 out of 2392 contours passed filtering
# 664	: 0 out of 5930 contours passed filtering
# 665	: 0 out of 1924 contours passed filtering
# 666	: 0 out of 2081 contours passed filtering
# 667	: 1 out of 3565 contours passed filtering
# 668	: 0 out of 3318 contours passed filtering
# 669	: 0 out of 3353 contours passed filtering
# 670	: 0 out of 2291 contours passed filtering
# 671	: 0 out of 2507 contours passed filtering
# 672	: 0 out of 2969 contours passed filtering
# 673	: 0 out of 2119 contours passed filtering
# 674	: 0 out of 2612 contours passed filtering
# 675	: 1 out of 3647 contours passed filtering
# 676	: 0 out of 2115 contours passed filtering
# 677	: 0 out of 2146 contours passed filtering
# 678	: 0 out of 1995 contours passed filtering
# 679	: 0 out of 2556 contours passed filtering
# 680	: 0 out of 2318 contours passed filtering
# 681	: 0 out of 2442 contours passed filtering
# 682	: 0 out of 2909 contours passed filtering
# 683	: 0 out of 2877 contours passed filtering
# 684	: 0 out of 3148 contours passed filtering
# 685	: 0 out of 3360 contours passed filtering
# 686	: 1 out of 2732 contours passed filtering
# 687	: 0 out of 2121 contours passed filtering
# 688	: 0 out of 2016 contours passed filtering
# 689	: 0 out of 2706 contours passed filtering
# 690	: 0 out of 3017 contours passed filtering
# 691	: 0 out of 3270 contours passed filtering
# 692	: 1 out of 3011 contours passed filtering
# 693	: 0 out of 3606 contours passed filtering
# 694	: 0 out of 2835 contours passed filtering
# 695	: 1 out of 2551 contours passed filtering
# 696	: 0 out of 2933 contours passed filtering
# 697	: 0 out of 2597 contours passed filtering
# 698	: 0 out of 2275 contours passed filtering
# 699	: 0 out of 2323 contours passed filtering
# 700	: 0 out of 3057 contours passed filtering
# 701	: 0 out of 1940 contours passed filtering
# 702	: 0 out of 1991 contours passed filtering
# 703	: 0 out of 2507 contours passed filtering
# 704	: 0 out of 3481 contours passed filtering
# 705	: 0 out of 2045 contours passed filtering
# 706	: 0 out of 2798 contours passed filtering
# 707	: 0 out of 1969 contours passed filtering
# 708	: 1 out of 2446 contours passed filtering
# 709	: 1 out of 2461 contours passed filtering
# 710	: 0 out of 2122 contours passed filtering
# 711	: 1 out of 3040 contours passed filtering
# 712	: 0 out of 2947 contours passed filtering
# 713	: 0 out of 3077 contours passed filtering
# 714	: 0 out of 2419 contours passed filtering
# 715	: 0 out of 3017 contours passed filtering
# 716	: 0 out of 2964 contours passed filtering
# 717	: 0 out of 2852 contours passed filtering
# 718	: 1 out of 3464 contours passed filtering
# 719	: 0 out of 2546 contours passed filtering
# 720	: 0 out of 2335 contours passed filtering
# 721	: 1 out of 2050 contours passed filtering
# 722	: 0 out of 1972 contours passed filtering
# 723	: 1 out of 2285 contours passed filtering
# 724	: 0 out of 3041 contours passed filtering
# 725	: 0 out of 2199 contours passed filtering
# 726	: 0 out of 1978 contours passed filtering
# 727	: 0 out of 2080 contours passed filtering
# 728	: 0 out of 2297 contours passed filtering
# 729	: 0 out of 2252 contours passed filtering
# 730	: 0 out of 2108 contours passed filtering
# 731	: 1 out of 2477 contours passed filtering
# 732	: 0 out of 3184 contours passed filtering
# 733	: 0 out of 2670 contours passed filtering
# 734	: 0 out of 3137 contours passed filtering
# 735	: 1 out of 1838 contours passed filtering
# 736	: 0 out of 2816 contours passed filtering
# 737	: 0 out of 2247 contours passed filtering
# 738	: 0 out of 2579 contours passed filtering
# 739	: 0 out of 2478 contours passed filtering
# 740	: 0 out of 2520 contours passed filtering
# 741	: 0 out of 2818 contours passed filtering
# 742	: 0 out of 2633 contours passed filtering
# 743	: 0 out of 3957 contours passed filtering
# 744	: 0 out of 3341 contours passed filtering
# 745	: 0 out of 2176 contours passed filtering
# 746	: 0 out of 2304 contours passed filtering
# 747	: 0 out of 2313 contours passed filtering
# 748	: 0 out of 2495 contours passed filtering
# 749	: 0 out of 2203 contours passed filtering
# 750	: 0 out of 3431 contours passed filtering
# 751	: 0 out of 3523 contours passed filtering
# 752	: 0 out of 2991 contours passed filtering
# 753	: 0 out of 2092 contours passed filtering
# 754	: 0 out of 3097 contours passed filtering
# 755	: 0 out of 2658 contours passed filtering
# 756	: 0 out of 3346 contours passed filtering
# 757	: 1 out of 3097 contours passed filtering
# 758	: 0 out of 2211 contours passed filtering
# 759	: 0 out of 2778 contours passed filtering
# 760	: 0 out of 2699 contours passed filtering
# 761	: 0 out of 2584 contours passed filtering
# 762	: 1 out of 2557 contours passed filtering
# 763	: 0 out of 3195 contours passed filtering
# 764	: 0 out of 2507 contours passed filtering
# 765	: 0 out of 3524 contours passed filtering
# 766	: 0 out of 2811 contours passed filtering
# 767	: 0 out of 3584 contours passed filtering
# 768	: 0 out of 2451 contours passed filtering
# 769	: 0 out of 1987 contours passed filtering
# 770	: 0 out of 3384 contours passed filtering
# 771	: 0 out of 2916 contours passed filtering
# 772	: 0 out of 3242 contours passed filtering
# 773	: 0 out of 2511 contours passed filtering
# 774	: 0 out of 1969 contours passed filtering
# 775	: 0 out of 2502 contours passed filtering
# 776	: 0 out of 3397 contours passed filtering
# 777	: 0 out of 2869 contours passed filtering
# 778	: 0 out of 2431 contours passed filtering
# 779	: 0 out of 2966 contours passed filtering
# 780	: 1 out of 3080 contours passed filtering
# 781	: 1 out of 3033 contours passed filtering
# 782	: 0 out of 1972 contours passed filtering
# 783	: 0 out of 3066 contours passed filtering
# 784	: 0 out of 2265 contours passed filtering
# 785	: 0 out of 2150 contours passed filtering
# 786	: 0 out of 3124 contours passed filtering
# 787	: 0 out of 2057 contours passed filtering
# 788	: 0 out of 2277 contours passed filtering
# 789	: 0 out of 1734 contours passed filtering
# 790	: 0 out of 2833 contours passed filtering
# 791	: 0 out of 3754 contours passed filtering
# 792	: 0 out of 3061 contours passed filtering
# 793	: 0 out of 2979 contours passed filtering
# 794	: 0 out of 1861 contours passed filtering
# 795	: 0 out of 3091 contours passed filtering
# 796	: 1 out of 3016 contours passed filtering
# 797	: 0 out of 2421 contours passed filtering
# 798	: 0 out of 3668 contours passed filtering
# 799	: 0 out of 2348 contours passed filtering
# 800	: 0 out of 3083 contours passed filtering
# 801	: 0 out of 1967 contours passed filtering
# 802	: 1 out of 2077 contours passed filtering
# 803	: 0 out of 2323 contours passed filtering
# 804	: 0 out of 2348 contours passed filtering
# 805	: 0 out of 3032 contours passed filtering
# 806	: 0 out of 2911 contours passed filtering
# 807	: 0 out of 3491 contours passed filtering
# 808	: 0 out of 3094 contours passed filtering
# 809	: 0 out of 3786 contours passed filtering
# 810	: 0 out of 3310 contours passed filtering
# 811	: 0 out of 2883 contours passed filtering
# 812	: 0 out of 2160 contours passed filtering
# 813	: 0 out of 2051 contours passed filtering
# 814	: 0 out of 2869 contours passed filtering
# 815	: 1 out of 2263 contours passed filtering
# 816	: 0 out of 2667 contours passed filtering
# 817	: 1 out of 2175 contours passed filtering
# 818	: 0 out of 3465 contours passed filtering
# 819	: 0 out of 2529 contours passed filtering
# 820	: 0 out of 3455 contours passed filtering
# 821	: 0 out of 2250 contours passed filtering
# 822	: 0 out of 2198 contours passed filtering
# 823	: 0 out of 3508 contours passed filtering
# 824	: 0 out of 2012 contours passed filtering
# 825	: 1 out of 2886 contours passed filtering
# 826	: 0 out of 2990 contours passed filtering
# 827	: 0 out of 2392 contours passed filtering
# 828	: 0 out of 2964 contours passed filtering
# 829	: 0 out of 2723 contours passed filtering
# 830	: 0 out of 3318 contours passed filtering
# 831	: 0 out of 1948 contours passed filtering
# 832	: 0 out of 3362 contours passed filtering
# 833	: 0 out of 2987 contours passed filtering
# 834	: 0 out of 3941 contours passed filtering
# 835	: 0 out of 2104 contours passed filtering
# 836	: 0 out of 2908 contours passed filtering
# 837	: 0 out of 3484 contours passed filtering
# 838	: 0 out of 3550 contours passed filtering
# 839	: 1 out of 3097 contours passed filtering
# 840	: 0 out of 2724 contours passed filtering
# 841	: 0 out of 2820 contours passed filtering
# 842	: 0 out of 2685 contours passed filtering
# 843	: 0 out of 3194 contours passed filtering
# 844	: 0 out of 2611 contours passed filtering
# 845	: 0 out of 3276 contours passed filtering
# 846	: 0 out of 2472 contours passed filtering
# 847	: 0 out of 2305 contours passed filtering
# 848	: 0 out of 2835 contours passed filtering
# 849	: 0 out of 3102 contours passed filtering
# 850	: 0 out of 3275 contours passed filtering
# 851	: 0 out of 2847 contours passed filtering
# 852	: 0 out of 2602 contours passed filtering
# 853	: 0 out of 2774 contours passed filtering
# 854	: 0 out of 2569 contours passed filtering
# 855	: 0 out of 3088 contours passed filtering
# 856	: 0 out of 3150 contours passed filtering
# 857	: 0 out of 2598 contours passed filtering
# 858	: 0 out of 3019 contours passed filtering
# 859	: 0 out of 2553 contours passed filtering
# 860	: 1 out of 2877 contours passed filtering
# 861	: 0 out of 2258 contours passed filtering
# 862	: 0 out of 3501 contours passed filtering
# 863	: 0 out of 1993 contours passed filtering
# 864	: 0 out of 2006 contours passed filtering
# 865	: 0 out of 2439 contours passed filtering
# 866	: 0 out of 2144 contours passed filtering
# 867	: 0 out of 2357 contours passed filtering
# 868	: 0 out of 2263 contours passed filtering
# 869	: 0 out of 3340 contours passed filtering
# 870	: 0 out of 2856 contours passed filtering
# 871	: 0 out of 3740 contours passed filtering
# 872	: 0 out of 2320 contours passed filtering
# 873	: 0 out of 2106 contours passed filtering
# 874	: 0 out of 3133 contours passed filtering
# 875	: 0 out of 2055 contours passed filtering
# 876	: 0 out of 2301 contours passed filtering
# 877	: 0 out of 2165 contours passed filtering
# 878	: 0 out of 2092 contours passed filtering
# 879	: 0 out of 2058 contours passed filtering
# 880	: 1 out of 2784 contours passed filtering
# 881	: 0 out of 1928 contours passed filtering
# 882	: 0 out of 2797 contours passed filtering
# 883	: 0 out of 3584 contours passed filtering
# 884	: 0 out of 4358 contours passed filtering
# 885	: 0 out of 3122 contours passed filtering
# 886	: 0 out of 2159 contours passed filtering
# 887	: 0 out of 3222 contours passed filtering
# 888	: 1 out of 2981 contours passed filtering
# 889	: 0 out of 3064 contours passed filtering
# 890	: 0 out of 3204 contours passed filtering
# 891	: 0 out of 2458 contours passed filtering
# 892	: 0 out of 2088 contours passed filtering
# 893	: 0 out of 2142 contours passed filtering
# 894	: 1 out of 3085 contours passed filtering
# 895	: 1 out of 3694 contours passed filtering
# 896	: 0 out of 2544 contours passed filtering
# 897	: 0 out of 2201 contours passed filtering
# 898	: 1 out of 3272 contours passed filtering
# 899	: 0 out of 3119 contours passed filtering
# 900	: 0 out of 2365 contours passed filtering
# 901	: 0 out of 2094 contours passed filtering
# 902	: 1 out of 3009 contours passed filtering
# 903	: 0 out of 2982 contours passed filtering
# 904	: 0 out of 2791 contours passed filtering
# 905	: 0 out of 3239 contours passed filtering
# 906	: 0 out of 2110 contours passed filtering
# 907	: 0 out of 2703 contours passed filtering
# 908	: 0 out of 2431 contours passed filtering
# 909	: 0 out of 2985 contours passed filtering
# 910	: 0 out of 1439 contours passed filtering
# 911	: 0 out of 2434 contours passed filtering
# 912	: 0 out of 2227 contours passed filtering
# 913	: 0 out of 3837 contours passed filtering
# 914	: 0 out of 2897 contours passed filtering
# 915	: 1 out of 3157 contours passed filtering
# 916	: 0 out of 3753 contours passed filtering
# 917	: 0 out of 2285 contours passed filtering
# 918	: 0 out of 3240 contours passed filtering
# 919	: 0 out of 3010 contours passed filtering
# 920	: 0 out of 3667 contours passed filtering
# 921	: 0 out of 2079 contours passed filtering
# 922	: 0 out of 2910 contours passed filtering
# 923	: 0 out of 2572 contours passed filtering
# 924	: 0 out of 2212 contours passed filtering
# 925	: 0 out of 2498 contours passed filtering
# 926	: 0 out of 2749 contours passed filtering
# 927	: 0 out of 1950 contours passed filtering
# 928	: 0 out of 3589 contours passed filtering
# 929	: 0 out of 2438 contours passed filtering
# 930	: 0 out of 1835 contours passed filtering
# 931	: 0 out of 2936 contours passed filtering
# 932	: 0 out of 2734 contours passed filtering
# 933	: 1 out of 3106 contours passed filtering
# 934	: 0 out of 2615 contours passed filtering
# 935	: 0 out of 3749 contours passed filtering
# 936	: 0 out of 3861 contours passed filtering
# 937	: 0 out of 2976 contours passed filtering
# 938	: 0 out of 3833 contours passed filtering
# 939	: 0 out of 1930 contours passed filtering
# 940	: 0 out of 2435 contours passed filtering
# 941	: 0 out of 3680 contours passed filtering
# 942	: 0 out of 2614 contours passed filtering
# 943	: 0 out of 2104 contours passed filtering
# 944	: 0 out of 3162 contours passed filtering
# 945	: 0 out of 2050 contours passed filtering
# 946	: 0 out of 3122 contours passed filtering
# 947	: 0 out of 2657 contours passed filtering
# 948	: 0 out of 2983 contours passed filtering
# 949	: 0 out of 2446 contours passed filtering
# 950	: 1 out of 3575 contours passed filtering
# 951	: 0 out of 2791 contours passed filtering
# 952	: 1 out of 2728 contours passed filtering
# 953	: 0 out of 2955 contours passed filtering
# 954	: 0 out of 2286 contours passed filtering
# 955	: 0 out of 2643 contours passed filtering
# 956	: 0 out of 2921 contours passed filtering
# 957	: 0 out of 2725 contours passed filtering
# 958	: 0 out of 2690 contours passed filtering
# 959	: 0 out of 3074 contours passed filtering
# 960	: 0 out of 3237 contours passed filtering
# 961	: 0 out of 2283 contours passed filtering
# 962	: 0 out of 2314 contours passed filtering
# 963	: 1 out of 2303 contours passed filtering
# 964	: 0 out of 3591 contours passed filtering
# 965	: 0 out of 3881 contours passed filtering
# 966	: 0 out of 1999 contours passed filtering
# 967	: 0 out of 3029 contours passed filtering
# 968	: 0 out of 3866 contours passed filtering
# 969	: 0 out of 2847 contours passed filtering
# 970	: 0 out of 3122 contours passed filtering
# 971	: 0 out of 2040 contours passed filtering
# 972	: 0 out of 2895 contours passed filtering
# 973	: 0 out of 2921 contours passed filtering
# 974	: 0 out of 2708 contours passed filtering
# 975	: 0 out of 2537 contours passed filtering
# 976	: 0 out of 3182 contours passed filtering
# 977	: 0 out of 3494 contours passed filtering
# 978	: 0 out of 2840 contours passed filtering
# 979	: 0 out of 2874 contours passed filtering
# 980	: 1 out of 2243 contours passed filtering
# 981	: 1 out of 3007 contours passed filtering
# 982	: 0 out of 2344 contours passed filtering
# 983	: 0 out of 3947 contours passed filtering
# 984	: 0 out of 2911 contours passed filtering
# 985	: 1 out of 1973 contours passed filtering
# 986	: 2 out of 2946 contours passed filtering
# 987	: 0 out of 2652 contours passed filtering
# 988	: 0 out of 2298 contours passed filtering
# 989	: 1 out of 2423 contours passed filtering
# 990	: 0 out of 5981 contours passed filtering
# 991	: 0 out of 2764 contours passed filtering
# 992	: 0 out of 2947 contours passed filtering
# 993	: 0 out of 2322 contours passed filtering
# 994	: 0 out of 2396 contours passed filtering
# 995	: 0 out of 2921 contours passed filtering
# 996	: 0 out of 2233 contours passed filtering
# 997	: 0 out of 2906 contours passed filtering
# 998	: 1 out of 2277 contours passed filtering
# 999	: 1 out of 2493 contours passed filtering
# 1000	: 1 out of 2910 contours passed filtering
# 1001	: 1 out of 2362 contours passed filtering
# 1002	: 0 out of 2172 contours passed filtering
# 1003	: 0 out of 2345 contours passed filtering
# 1004	: 0 out of 3699 contours passed filtering
# 1005	: 0 out of 2715 contours passed filtering
# 1006	: 0 out of 3270 contours passed filtering
# 1007	: 1 out of 3316 contours passed filtering
# 1008	: 0 out of 1837 contours passed filtering
# 1009	: 0 out of 2219 contours passed filtering
# 1010	: 0 out of 2154 contours passed filtering
# 1011	: 0 out of 3737 contours passed filtering
# 1012	: 0 out of 2514 contours passed filtering
# 1013	: 1 out of 3417 contours passed filtering
# 1014	: 0 out of 3250 contours passed filtering
# 1015	: 0 out of 1824 contours passed filtering
# 1016	: 0 out of 3923 contours passed filtering
# 1017	: 0 out of 2628 contours passed filtering
# 1018	: 0 out of 2605 contours passed filtering
# 1019	: 0 out of 2849 contours passed filtering
# 1020	: 0 out of 2313 contours passed filtering
# 1021	: 0 out of 2932 contours passed filtering
# 1022	: 0 out of 2031 contours passed filtering
# 1023	: 0 out of 2405 contours passed filtering
# 1024	: 0 out of 3264 contours passed filtering
# 1025	: 0 out of 1838 contours passed filtering
# 1026	: 0 out of 2345 contours passed filtering
# 1027	: 1 out of 2895 contours passed filtering
# 1028	: 0 out of 3333 contours passed filtering
# 1029	: 0 out of 2648 contours passed filtering
# 1030	: 0 out of 2261 contours passed filtering
# 1031	: 0 out of 2530 contours passed filtering
# 1032	: 0 out of 2623 contours passed filtering
# 1033	: 0 out of 2426 contours passed filtering
# 1034	: 0 out of 3484 contours passed filtering
# 1035	: 0 out of 2701 contours passed filtering
# 1036	: 0 out of 1988 contours passed filtering
# 1037	: 0 out of 3024 contours passed filtering
# 1038	: 0 out of 2192 contours passed filtering
# 1039	: 0 out of 2960 contours passed filtering
# 1040	: 1 out of 2565 contours passed filtering
# 1041	: 0 out of 2652 contours passed filtering
# 1042	: 0 out of 2159 contours passed filtering
# 1043	: 0 out of 2954 contours passed filtering
# ...
# 8161	: 0 out of 2462 contours passed filtering
# 8162	: 0 out of 2001 contours passed filtering
# 8163	: 0 out of 2329 contours passed filtering
# 8164	: 0 out of 2077 contours passed filtering
# 8165	: 0 out of 1928 contours passed filtering
# 8166	: 0 out of 3059 contours passed filtering
# 8167	: 0 out of 2697 contours passed filtering
# 8168	: 0 out of 3601 contours passed filtering
# 8169	: 0 out of 2322 contours passed filtering
# 8170	: 0 out of 2815 contours passed filtering
# 8171	: 0 out of 2447 contours passed filtering
# 8172	: 1 out of 1959 contours passed filtering
# 8173	: 0 out of 2029 contours passed filtering
# 8174	: 0 out of 2856 contours passed filtering
# 8175	: 0 out of 3031 contours passed filtering
# 8176	: 0 out of 2009 contours passed filtering
# 8177	: 0 out of 2934 contours passed filtering
# 8178	: 2 out of 2611 contours passed filtering
# 8179	: 1 out of 2650 contours passed filtering
# 8180	: 0 out of 2326 contours passed filtering
# 8181	: 1 out of 2195 contours passed filtering
# 8182	: 0 out of 2960 contours passed filtering
# 8183	: 0 out of 3781 contours passed filtering
# 8184	: 0 out of 2605 contours passed filtering
# 8185	: 0 out of 2387 contours passed filtering
# 8186	: 0 out of 2785 contours passed filtering
# 8187	: 0 out of 2264 contours passed filtering
# 8188	: 0 out of 1961 contours passed filtering
# 8189	: 0 out of 2259 contours passed filtering
# 8190	: 0 out of 2109 contours passed filtering
# 8191	: 0 out of 2637 contours passed filtering
# 8192	: 1 out of 2174 contours passed filtering
# 8193	: 0 out of 5205 contours passed filtering
# 8194	: 0 out of 3153 contours passed filtering
# 8195	: 0 out of 2103 contours passed filtering
# 8196	: 0 out of 3330 contours passed filtering
# 8197	: 0 out of 2623 contours passed filtering
# 8198	: 0 out of 1961 contours passed filtering
# 8199	: 0 out of 3274 contours passed filtering
# 8200	: 0 out of 2903 contours passed filtering
# 8201	: 0 out of 3555 contours passed filtering
# 8202	: 0 out of 3941 contours passed filtering
# 8203	: 0 out of 2210 contours passed filtering
# 8204	: 0 out of 2068 contours passed filtering
# 8205	: 1 out of 2527 contours passed filtering
# 8206	: 0 out of 2792 contours passed filtering
# 8207	: 0 out of 1884 contours passed filtering
# 8208	: 0 out of 2721 contours passed filtering
# 8209	: 1 out of 2988 contours passed filtering
# 8210	: 0 out of 2107 contours passed filtering
# 8211	: 0 out of 3029 contours passed filtering
# 8212	: 0 out of 2546 contours passed filtering
# 8213	: 0 out of 3305 contours passed filtering
# 8214	: 0 out of 2634 contours passed filtering
# 8215	: 1 out of 2190 contours passed filtering
# 8216	: 0 out of 3340 contours passed filtering
# 8217	: 0 out of 1933 contours passed filtering
# 8218	: 0 out of 2502 contours passed filtering
# 8219	: 0 out of 2579 contours passed filtering
# 8220	: 0 out of 3336 contours passed filtering
# 8221	: 0 out of 1781 contours passed filtering
# 8222	: 0 out of 2814 contours passed filtering
# 8223	: 0 out of 2270 contours passed filtering
# 8224	: 0 out of 2887 contours passed filtering
# 8225	: 0 out of 2287 contours passed filtering
# 8226	: 0 out of 3577 contours passed filtering
# 8227	: 1 out of 2847 contours passed filtering
# 8228	: 1 out of 2576 contours passed filtering
# 8229	: 0 out of 2396 contours passed filtering
# 8230	: 0 out of 3044 contours passed filtering
# 8231	: 0 out of 3685 contours passed filtering
# 8232	: 0 out of 3371 contours passed filtering
# 8233	: 0 out of 2905 contours passed filtering
# 8234	: 1 out of 2500 contours passed filtering
# 8235	: 0 out of 2989 contours passed filtering
# 8236	: 0 out of 2069 contours passed filtering
# 8237	: 1 out of 2861 contours passed filtering
# 8238	: 1 out of 3702 contours passed filtering
# 8239	: 0 out of 2160 contours passed filtering
# 8240	: 0 out of 2192 contours passed filtering
# 8241	: 0 out of 2397 contours passed filtering
# 8242	: 0 out of 2597 contours passed filtering
# 8243	: 1 out of 3001 contours passed filtering
# 8244	: 0 out of 3343 contours passed filtering
# 8245	: 0 out of 3177 contours passed filtering
# 8246	: 0 out of 2516 contours passed filtering
# 8247	: 1 out of 3063 contours passed filtering
# 8248	: 0 out of 2138 contours passed filtering
# 8249	: 1 out of 2121 contours passed filtering
# 8250	: 0 out of 2298 contours passed filtering
# 8251	: 0 out of 2504 contours passed filtering
# 8252	: 0 out of 2450 contours passed filtering
# 8253	: 0 out of 2536 contours passed filtering
# 8254	: 0 out of 1817 contours passed filtering
# 8255	: 0 out of 2548 contours passed filtering
# 8256	: 0 out of 2251 contours passed filtering
# 8257	: 1 out of 3317 contours passed filtering
# 8258	: 0 out of 2616 contours passed filtering
# 8259	: 1 out of 2346 contours passed filtering
# 8260	: 0 out of 2515 contours passed filtering
# 8261	: 0 out of 2802 contours passed filtering
# 8262	: 0 out of 3204 contours passed filtering
# 8263	: 1 out of 2409 contours passed filtering
# 8264	: 0 out of 2477 contours passed filtering
# 8265	: 0 out of 3295 contours passed filtering
# 8266	: 0 out of 2778 contours passed filtering
# 8267	: 0 out of 1874 contours passed filtering
# 8268	: 0 out of 2915 contours passed filtering
# 8269	: 0 out of 2727 contours passed filtering
# 8270	: 0 out of 2396 contours passed filtering
# 8271	: 0 out of 1983 contours passed filtering
# 8272	: 0 out of 2275 contours passed filtering
# 8273	: 1 out of 1825 contours passed filtering
# 8274	: 0 out of 2840 contours passed filtering
# 8275	: 1 out of 2327 contours passed filtering
# 8276	: 0 out of 2369 contours passed filtering
# 8277	: 0 out of 2977 contours passed filtering
# 8278	: 0 out of 2965 contours passed filtering
# 8279	: 0 out of 2316 contours passed filtering
# 8280	: 0 out of 2376 contours passed filtering
# 8281	: 0 out of 2313 contours passed filtering
# 8282	: 0 out of 2916 contours passed filtering
# 8283	: 0 out of 2764 contours passed filtering
# 8284	: 0 out of 3169 contours passed filtering
# 8285	: 1 out of 2114 contours passed filtering
# 8286	: 0 out of 2084 contours passed filtering
# 8287	: 0 out of 2494 contours passed filtering
# 8288	: 0 out of 3089 contours passed filtering
# 8289	: 0 out of 2240 contours passed filtering
# 8290	: 0 out of 1954 contours passed filtering
# 8291	: 0 out of 2823 contours passed filtering
# 8292	: 0 out of 2994 contours passed filtering
# 8293	: 0 out of 3091 contours passed filtering
# 8294	: 0 out of 3045 contours passed filtering
# 8295	: 0 out of 3013 contours passed filtering
# 8296	: 0 out of 3661 contours passed filtering
# 8297	: 0 out of 2897 contours passed filtering
# 8298	: 0 out of 977 contours passed filtering
# 8299	: 0 out of 2420 contours passed filtering
# 8300	: 0 out of 3207 contours passed filtering
# 8301	: 0 out of 2878 contours passed filtering
# 8302	: 0 out of 2547 contours passed filtering
# 8303	: 0 out of 3637 contours passed filtering
# 8304	: 0 out of 2704 contours passed filtering
# 8305	: 0 out of 1897 contours passed filtering
# 8306	: 0 out of 2782 contours passed filtering
# 8307	: 1 out of 2320 contours passed filtering
# 8308	: 0 out of 2337 contours passed filtering
# 8309	: 0 out of 2831 contours passed filtering
# 8310	: 0 out of 3844 contours passed filtering
# 8311	: 0 out of 2932 contours passed filtering
# 8312	: 0 out of 3028 contours passed filtering
# 8313	: 0 out of 1960 contours passed filtering
# 8314	: 1 out of 2959 contours passed filtering
# 8315	: 0 out of 2810 contours passed filtering
# 8316	: 0 out of 4417 contours passed filtering
# 8317	: 0 out of 3487 contours passed filtering
# 8318	: 0 out of 2873 contours passed filtering
# 8319	: 0 out of 2347 contours passed filtering
# 8320	: 1 out of 2673 contours passed filtering
# 8321	: 0 out of 1930 contours passed filtering
# 8322	: 0 out of 2703 contours passed filtering
# 8323	: 0 out of 1756 contours passed filtering
# 8324	: 0 out of 2051 contours passed filtering
# 8325	: 0 out of 2296 contours passed filtering
# 8326	: 1 out of 2655 contours passed filtering
# 8327	: 0 out of 2466 contours passed filtering
# 8328	: 0 out of 3404 contours passed filtering
# 8329	: 0 out of 1981 contours passed filtering
# 8330	: 0 out of 2940 contours passed filtering
# 8331	: 0 out of 1790 contours passed filtering
# 8332	: 0 out of 2139 contours passed filtering
# 8333	: 1 out of 3204 contours passed filtering
# 8334	: 1 out of 3004 contours passed filtering
# 8335	: 0 out of 2094 contours passed filtering
# 8336	: 0 out of 3156 contours passed filtering
# 8337	: 0 out of 2894 contours passed filtering
# 8338	: 0 out of 2807 contours passed filtering
# 8339	: 0 out of 2020 contours passed filtering
# 8340	: 1 out of 2020 contours passed filtering
# 8341	: 0 out of 3894 contours passed filtering
# 8342	: 0 out of 3094 contours passed filtering
# 8343	: 0 out of 2287 contours passed filtering
# 8344	: 0 out of 2307 contours passed filtering
# 8345	: 0 out of 1845 contours passed filtering
# 8346	: 0 out of 2876 contours passed filtering
# 8347	: 0 out of 2332 contours passed filtering
# 8348	: 0 out of 2454 contours passed filtering
# 8349	: 0 out of 3328 contours passed filtering
# 8350	: 0 out of 2202 contours passed filtering
# 8351	: 0 out of 3620 contours passed filtering
# 8352	: 0 out of 3196 contours passed filtering
# 8353	: 0 out of 2370 contours passed filtering
# 8354	: 0 out of 3865 contours passed filtering
# 8355	: 0 out of 2195 contours passed filtering
# 8356	: 0 out of 2678 contours passed filtering
# 8357	: 0 out of 3399 contours passed filtering
# 8358	: 0 out of 4474 contours passed filtering
# 8359	: 0 out of 2104 contours passed filtering
# 8360	: 0 out of 2882 contours passed filtering
# 8361	: 0 out of 3003 contours passed filtering
# 8362	: 0 out of 3569 contours passed filtering
# 8363	: 0 out of 2047 contours passed filtering
# 8364	: 1 out of 2728 contours passed filtering
# 8365	: 0 out of 2627 contours passed filtering
# 8366	: 0 out of 2926 contours passed filtering
# 8367	: 0 out of 2898 contours passed filtering
# 8368	: 0 out of 3444 contours passed filtering
# 8369	: 1 out of 2582 contours passed filtering
# 8370	: 0 out of 2172 contours passed filtering
# 8371	: 1 out of 3025 contours passed filtering
# 8372	: 0 out of 2428 contours passed filtering
# 8373	: 0 out of 2867 contours passed filtering
# 8374	: 0 out of 2168 contours passed filtering
# 8375	: 0 out of 3719 contours passed filtering
# 8376	: 0 out of 3089 contours passed filtering
# 8377	: 0 out of 1903 contours passed filtering
# 8378	: 0 out of 2816 contours passed filtering
# 8379	: 0 out of 2505 contours passed filtering
# 8380	: 0 out of 2597 contours passed filtering
# 8381	: 0 out of 3094 contours passed filtering
# 8382	: 0 out of 2153 contours passed filtering
# 8383	: 1 out of 2504 contours passed filtering
# 8384	: 0 out of 2210 contours passed filtering
# 8385	: 1 out of 2993 contours passed filtering
# 8386	: 0 out of 2782 contours passed filtering
# 8387	: 0 out of 2945 contours passed filtering
# 8388	: 1 out of 2236 contours passed filtering
# 8389	: 0 out of 2413 contours passed filtering
# 8390	: 0 out of 3161 contours passed filtering
# 8391	: 0 out of 2118 contours passed filtering
# 8392	: 0 out of 2964 contours passed filtering
# 8393	: 0 out of 3241 contours passed filtering
# 8394	: 0 out of 2708 contours passed filtering
# 8395	: 0 out of 2471 contours passed filtering
# 8396	: 0 out of 2603 contours passed filtering
# 8397	: 0 out of 2710 contours passed filtering
# 8398	: 0 out of 3084 contours passed filtering
# 8399	: 0 out of 3680 contours passed filtering
# 8400	: 0 out of 1982 contours passed filtering
# 8401	: 0 out of 3058 contours passed filtering
# 8402	: 0 out of 2213 contours passed filtering
# 8403	: 0 out of 2900 contours passed filtering
# 8404	: 0 out of 2132 contours passed filtering
# 8405	: 0 out of 2734 contours passed filtering
# 8406	: 0 out of 2905 contours passed filtering
# 8407	: 0 out of 2082 contours passed filtering
# 8408	: 0 out of 2839 contours passed filtering
# 8409	: 0 out of 2887 contours passed filtering
# 8410	: 0 out of 2791 contours passed filtering
# 8411	: 0 out of 2687 contours passed filtering
# 8412	: 0 out of 2408 contours passed filtering
# 8413	: 0 out of 2956 contours passed filtering
# 8414	: 0 out of 2475 contours passed filtering
# 8415	: 0 out of 2371 contours passed filtering
# 8416	: 1 out of 1843 contours passed filtering
# 8417	: 0 out of 2176 contours passed filtering
# 8418	: 0 out of 2227 contours passed filtering
# 8420	: 0 out of 2330 contours passed filtering
# 8421	: 0 out of 2817 contours passed filtering
# 8422	: 1 out of 2976 contours passed filtering
# 8423	: 1 out of 2987 contours passed filtering
# 8424	: 0 out of 2045 contours passed filtering
# 8425	: 0 out of 2615 contours passed filtering
# 8426	: 0 out of 2393 contours passed filtering
# 8427	: 0 out of 2986 contours passed filtering
# 8428	: 0 out of 3785 contours passed filtering
# 8429	: 0 out of 2258 contours passed filtering
# 8430	: 0 out of 3036 contours passed filtering
# 8431	: 0 out of 2296 contours passed filtering
# 8432	: 0 out of 2624 contours passed filtering
# 8433	: 0 out of 3946 contours passed filtering
# 8434	: 0 out of 2442 contours passed filtering
# 8435	: 0 out of 2395 contours passed filtering
# 8436	: 0 out of 2860 contours passed filtering
# 8437	: 1 out of 2191 contours passed filtering
# 8438	: 0 out of 4398 contours passed filtering
# 8439	: 0 out of 2946 contours passed filtering
# 8440	: 0 out of 2588 contours passed filtering
# 8441	: 0 out of 1671 contours passed filtering
# 8442	: 0 out of 2504 contours passed filtering
# 8443	: 1 out of 2722 contours passed filtering
# 8444	: 0 out of 1906 contours passed filtering
# 8445	: 0 out of 1805 contours passed filtering
# 8446	: 0 out of 2136 contours passed filtering
# 8447	: 0 out of 3234 contours passed filtering
# 8448	: 0 out of 3059 contours passed filtering
# 8449	: 0 out of 2909 contours passed filtering
# 8450	: 0 out of 2528 contours passed filtering
# 8451	: 0 out of 2620 contours passed filtering
# 8452	: 0 out of 3730 contours passed filtering
# 8453	: 0 out of 2467 contours passed filtering
# 8454	: 0 out of 2832 contours passed filtering
# 8455	: 0 out of 3684 contours passed filtering
# 8456	: 1 out of 2594 contours passed filtering
# 8457	: 0 out of 2840 contours passed filtering
# 8458	: 0 out of 2084 contours passed filtering
# 8459	: 0 out of 2408 contours passed filtering
# 8460	: 1 out of 2969 contours passed filtering
# 8461	: 0 out of 2548 contours passed filtering
# 8462	: 0 out of 2356 contours passed filtering
# 8463	: 0 out of 3059 contours passed filtering
# 8464	: 0 out of 2330 contours passed filtering
# 8465	: 0 out of 2940 contours passed filtering
# 8466	: 0 out of 2362 contours passed filtering
# 8467	: 1 out of 2386 contours passed filtering
# 8468	: 0 out of 2918 contours passed filtering
# 8469	: 0 out of 3110 contours passed filtering
# 8470	: 0 out of 2949 contours passed filtering
# 8471	: 0 out of 3275 contours passed filtering
# 8472	: 0 out of 3235 contours passed filtering
# 8473	: 0 out of 2438 contours passed filtering
# 8474	: 1 out of 3226 contours passed filtering
# 8475	: 0 out of 2432 contours passed filtering
# 8476	: 0 out of 2179 contours passed filtering
# 8477	: 0 out of 2127 contours passed filtering
# 8478	: 0 out of 3448 contours passed filtering
# 8479	: 1 out of 2928 contours passed filtering
# 8480	: 0 out of 3452 contours passed filtering
# 8481	: 0 out of 2105 contours passed filtering
# 8482	: 0 out of 1968 contours passed filtering
# 8483	: 1 out of 3104 contours passed filtering
# 8484	: 0 out of 2983 contours passed filtering
# 8485	: 0 out of 2618 contours passed filtering
# 8486	: 1 out of 2157 contours passed filtering
# 8487	: 0 out of 3010 contours passed filtering
# 8488	: 0 out of 2281 contours passed filtering
# 8489	: 1 out of 2370 contours passed filtering
# 8490	: 0 out of 1961 contours passed filtering
# 8491	: 0 out of 2444 contours passed filtering
# 8492	: 0 out of 3137 contours passed filtering
# 8493	: 0 out of 3200 contours passed filtering
# 8494	: 0 out of 3077 contours passed filtering
# 8495	: 1 out of 2682 contours passed filtering
# 8496	: 0 out of 2381 contours passed filtering
# 8497	: 0 out of 2513 contours passed filtering
# 8498	: 0 out of 2516 contours passed filtering
# 8499	: 0 out of 2758 contours passed filtering
# 8500	: 0 out of 2300 contours passed filtering
# 8501	: 0 out of 3005 contours passed filtering

# %%
# Bounding boxes supplied in format: [x, y, width, height]
def calc_iou(bbA, bbB):                   #top L     top R     bottom R   bottom L
    # Bounding boxes converted to format: [[x1, y1], [x2, y2], [x3, y3], [x4, y4]]
    bbA = Polygon([[bbA[0], bbA[1]], [bbA[0]+bbA[2], bbA[1]], [bbA[0]+bbA[2], bbA[1]-bbA[3]], [bbA[0], bbA[1]-bbA[3]]])
    bbB = Polygon([[bbB[0], bbB[1]], [bbB[0]+bbB[2], bbB[1]], [bbB[0]+bbB[2], bbB[1]-bbB[3]], [bbB[0], bbB[1]-bbB[3]]])
    
    iou = bbA.intersection(bbB).area / bbA.union(bbB).area
    return iou

# %%
gtf1 = os.listdir("../advanced_model/YOLOv5 Master/test/labels/")
gtf2 = os.listdir("../advanced_model/YOLOv5 Master/train/labels/")
gtf3 = os.listdir("../advanced_model/YOLOv5 Master/valid/labels/")

for i in range(len(gtf1)):
    gtf1[i] = "test/labels/" + gtf1[i]

for i in range(len(gtf2)):
    gtf2[i] = "train/labels/" + gtf2[i]

for i in range(len(gtf3)):
    gtf3[i] = "valid/labels/" + gtf3[i]

gt_files = gtf1 + gtf2 + gtf3

# %%
ious = []
no_pred = 0
for i in range(len(all_filtered_cons)):
    # Continue if list of predictions is empty
    if len(all_filtered_cons[i][0]) == 0:
        no_pred += 1
        continue

    time_stamp = all_filtered_cons[i][1].split("_")[0].split("+")[0] + "-0900"

    # Serch through ground truth files for the file beloning to current predictions
    for gtf in gt_files:
        if time_stamp in gtf:
            truth_file = gtf
            break
    # Test if a ground truth file could be found
    try:
        print(truth_file, end="\r")
    except:
        continue

    # Read annotation file with ground truth BB location
    f = open("../advanced_model/YOLOv5 Master/" + truth_file, "r")
    contents = f.readlines()
    f.close()
    del truth_file

    # Get ground truth BB values
    gtxc, gtyc, gtw, gth = [round(float(num)*1280) for num in contents[0].split()[1:5]]
    gtyc = round((gtyc/1280)*720)
    gtx = gtxc - round((gtw/2))
    gty = gtyc - round((((gth/1280)*720)/2))
    gt = [gtx, gty, gtw, gth]

    # If the number of bounding boxes is higher than  one loop over them to calculate IoU
    if len(all_filtered_cons[i][0]) > 1:
        for j in range(len(all_filtered_cons[i][0])):
            bb = cv.boundingRect(all_filtered_cons[i][0][j])
            iou = calc_iou(gt, bb)
            ious.append([iou, i])
    # Calculate IoU for single bounding box
    else:
        bb = cv.boundingRect(all_filtered_cons[i][0][0])
        iou = calc_iou(gt, bb)
        ious.append([iou, i])
    
    # print(gt)
    # print(bb)
    # print(iou)
    # img = cv.imread("test_data_10000/" + "+".join(time_stamp.split("-")) + "_infrared_image.png")
    # cv.rectangle(img, pt1=(bb[0], bb[1]), pt2=(bb[0]+bb[2], bb[1]+bb[3]), color=(0, 0, 255), thickness=2)
    # cv.rectangle(img, pt1=(gt[0], gt[1]), pt2=(gt[0]+gt[2], gt[1]+gt[3]), color=(0, 255, 0), thickness=2)
    # cv.imshow("test", img)
    # k = cv.waitKey(0)
    # cv.destroyWindow("test")
    # cv.waitKey(1)
    # if k == ord("q"):
    #     break

no_pred
# Out:
# test/labels/20200122T113558-0900_infrared_image_png.rf.23a557ccdae6bf98b6d32b65c993eeb2.txtt
# 7399

# %%
k = 0
for i in range(len(all_filtered_cons)):
    if len(all_filtered_cons[i][0]) >= 2:
        k += 1
k
# Out:
# 30

# %%
print("### CONTOUR DETECTION MODEL RESULTS")
thres = [0.01, 0.5, 0.75]
for t in thres:
    true_pos = 0
    false_pos = 0
    false_neg = 0

    for i in range(len(all_filtered_cons)):
        if all_filtered_cons[i][0] == []:
            time_stamp = all_filtered_cons[i][1].split("_")[0]
            x = bb_df.loc[bb_df["timestamp"] == time_stamp, "x"].item()
            y = bb_df.loc[bb_df["timestamp"] == time_stamp, "y"].item()
            if not (x == 0 and y == 0):
                false_neg += 1
        elif len(all_filtered_cons[i][0]) == 1:
            for j in range(len(ious)):
                if ious[j][1] == i:
                    if ious[j][0] >= t:
                        true_pos += 1
                    if ious[j][0] < t:
                        false_pos += 1
                    break

    print("IoU threshold = ", t)
    print("\tTrue pos:\t", true_pos)
    print("\tFalse pos:\t", false_pos)
    print("\tFalse Neg:\t", false_neg)
    print("\tPrecision:\t", true_pos / (true_pos+false_pos))
    print("\tRecall:\t\t", true_pos / (true_pos+false_neg))
# Out:
# ### CONTOUR DETECTION MODEL RESULTS
# IoU threshold =  0.01
# 	True pos:	 760
# 	False pos:	 311
# 	False Neg:	 7370
# 	Precision:	 0.7096171802054155
# 	Recall:		 0.09348093480934809
# IoU threshold =  0.5
# 	True pos:	 420
# 	False pos:	 651
# 	False Neg:	 7370
# 	Precision:	 0.39215686274509803
# 	Recall:		 0.05391527599486521
# IoU threshold =  0.75
# 	True pos:	 236
# 	False pos:	 835
# 	False Neg:	 7370
# 	Precision:	 0.2203548085901027
# 	Recall:		 0.031028135682356035

# %% [markdown]
# ### CONTOUR DETECTION MODEL RESULTS (most precise)
# IoU threshold =  0.01<br>
# &emsp;True pos:	 760<br>
# &emsp;False pos:	 311<br>
# &emsp;False Neg:	 7370<br>
# &emsp;Precision:	 0.7096171802054155<br>
# &emsp;Recall:		 0.09348093480934809<br>
# <br>
# IoU threshold =  0.5<br>
# &emsp;True pos:	 420<br>
# &emsp;False pos:	 651<br>
# &emsp;False Neg:	 7370<br>
# &emsp;Precision:	 0.39215686274509803<br>
# &emsp;Recall:		 0.05391527599486521<br>
# <br>
# IoU threshold =  0.75<br>
# &emsp;True pos:	 236<br>
# &emsp;False pos:	 835<br>
# &emsp;False Neg:	 7370<br>
# &emsp;Precision:	 0.2203548085901027<br>
# &emsp;Recall:		 0.031028135682356035<br>

# %% [markdown]
# ### CONTOUR DETECTION MODEL RESULTS
# IoU threshold =  0.01
# <br>&emsp;Precision:&emsp;	 0.7096171802054155
# <br>&emsp;Recall:&emsp;		 0.09348093480934809
#
# <br><br>IoU threshold =  0.1
# <br>&emsp;Precision:&emsp;	 0.6657329598506069
# <br>&emsp;Recall:&emsp;		 0.08820982308548807
#
# <br><br>IoU threshold =  0.5
# <br>&emsp;Precision:&emsp;	 0.36134453781512604
# <br>&emsp;Recall:&emsp;		 0.04989042155472476
#
# <br><br>IoU threshold =  0.75
# <br>&emsp;Precision:&emsp;	 0.19794584500466852
# <br>&emsp;Recall:&emsp;		 0.02796096016882089
